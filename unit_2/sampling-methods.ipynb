# %% [markdown]
# # SAMPLE SELECTION IN RESEARCH
# **BS Lưu Lâm Thắng Tài**

# %% [markdown]
# # 1. Một số khái niệm
# 1. Target population
# 2. Study population (Accessible population)
# 3. Sampling frame
# 4. Sample
#
# <img src="https://image.slidesharecdn.com/samplingtechnique-150727180828-lva1-app6892/95/sampling-techniques-11-638.jpg?cb=1438020689"></img>

# %% [markdown]
# # 2. Câu chuyện
#
# ## Một nghiên cứu về các đặc điểm liên quan đến sự tuân thủ điều trị đái tháo đường.
# - *Target population:* tất cả bn ĐTĐ.
# - *Study population:* bn tại BV X.
# - *Sampling frame:* bn ngoại trú tại BV X trong khoảng thời gian nhất định.
# - *Sampling method:* simple random sampling ( ngẫu nhiên đơn)
# - *Sample size:* 384 bn (dựa trên công thức)
# $$ n = \frac {Z^2_{1-\alpha/2} *p*(1-p)}{d^2} $$
# - *Data collecting method:* questionaire
# - *Các biến độc lập:* dựa trên **MMAS-8**

# %% [markdown]
# <table>
#         <thead>
#             <tr>
#                 <th rowspan="2">Đặc điểm khảo sát</br>thông tin chung</br>của bệnh nhân</th>
#                 <th colspan="3">Mức độ tuân thủ điều trị theo MMAS-8</th>
#                 <th rowspan="2">p-value</th>
#             </tr>
#             <tr>
#                 <th>Thấp N=51</th>
#                 <th>Trung bình N=115</th>
#                 <th>Cao N=124</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <th align='left'>Giới tính</th>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.242</td>
#             </tr>
#             <tr>
#                 <td>Nam</td>
#                 <td>23(45.1)</td>
#                 <td>45(39.1)</td>
#                 <td>23(45.1)</td>
#             </tr>
#             <tr>
#                 <td>Nữ</td>
#                 <td>28(54.9)</td>
#                 <td>70(60.9)</td>
#                 <td>28(54.9)</td>
#             </tr>
#             <tr>
#                 <th align='left'>Tuổi</th>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td><b>0.049</b></td>
#             </tr>
#             <tr>
#                 <td>Giá trị</td>
#                 <td>59.1$\pm$9.1</td>
#                 <td>62.9$\pm$10.3</td>
#                 <td>63$\pm$10.7</td>
#             </tr>
#         </tbody>
#     </table>

# %% [markdown]
# Kết quả khi thu về, nhóm tác giả thấy *độ tuổi* có ý nghĩa thống kê đến mức độ tuân thủ điều trị. Cụ thể, những bệnh nhân có độ tuổi càng cao thì càng tuân thủ điều trị hơn → Là kết quả có thể biện luận được!

# %% [markdown]
# <table>
#         <thead>
#             <tr>
#                 <th rowspan="2">Tác dụng phụ</br>của thuốc</th>
#                 <th colspan="3">Mức độ tuân thủ điều trị theo MMAS-8</th>
#                 <th rowspan="2">p-value</th>
#             </tr>
#             <tr>
#                 <th>Thấp N=51</th>
#                 <th>Trung bình N=115</th>
#                 <th>Cao N=124</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <th align='left'>Tăng cân</th>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td>0.101</td>
#             </tr>
#             <tr>
#                 <td>Có</td>
#                 <td>3(5.9)</td>
#                 <td>4(3.5)</td>
#                 <td>1(0.8)</td>
#             </tr>
#             <tr>
#                 <td>Không</td>
#                 <td>48(94.1)</td>
#                 <td>111(86.5)</td>
#                 <td>123(99.2)</td>
#             </tr>
#             <tr>
#                 <th align='left'>Phù, phát ban</th>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#                 <td><b>0.018</b></td>
#             </tr>
#             <tr>
#                 <td>Có</td>
#                 <td>2(3.9)</td>
#                 <td>23(20.0)</td>
#                 <td>19(15.3)</td>
#             </tr>
#             <tr>
#                 <td>Không</td>
#                 <td>49(96.1)</td>
#                 <td>92(80.0)</td>
#                 <td>105(84.7)</td>
#             </tr>
#         </tbody>
#     </table>

# %% [markdown]
# Tuy nhiên khi xét đến tác dụng phụ của thuốc, nhóm tác giả ghi nhận một kết quả “lạ” rất khó giải thích !!!!
#
# **Vấn đề nằm ở đâu ?**

# %% [markdown]
# ## Giả sử bạn là trợ lý của Bộ trưởng Bộ Nông nghiệp của Nga.
# Sếp bạn thấy Nga hiện tại rất phát triển ngành chăn nuôi heo với cung vượt qua cầu, nên muốn xuất khẩu thịt heo sang các nước khác (cụ thể là các nước châu Á).
# Sếp chọn Indonesia làm nơi thử nghiệm thị trường đầu tiên vì:
# 1. Đó là nước có tỉ lệ mậu dịch khá cao với Nga và có quan hệ quốc tế như một đối tác chiến lược về kinh tế,
# 2. Ngành chăn nuôi heo không phát triển ở Indonesia.
#
# Sếp giao cho bạn … mấy trăm tấn thịt heo và yêu cầu bạn lập khảo sát thị hiếu của người dân Indonesia và lập chiến lược kinh doanh. Nhiệm vụ của bạn là sau 3 năm bằng mọi cách phải đảm bảo xuất khẩu thịt heo 800 tấn/năm.
# **Bạn sẽ làm gì ???**

# %% [markdown]
# ---
# 1. Quan hệ giữa *target population* và *research question* phải hợp lý về mặt logic. Tương tự là mối quan hệ giữa *study population* và *research question*.
# 2. Khi chọn đối tượng khảo sát, nên đặt câu hỏi giữa 2 nhóm *“accessible population”* và *“non-accessible population”*, liệu có sự khác biệt đáng kể hay không.
# 3. Nếu có thể, luôn có gắng để *study population* gần giống với *target population* nhiều nhất có thể.!

# %% [markdown]
# # 3. Ý nghĩa của sampling
#
# ## Quay lại câu chuyện tuân thủ điều trị ĐTĐ
# Để làm được random sampling, trên lý thuyết nhóm tác giả phải có trước đó danh sách bệnh nhân sẽ đến khám vào các ngày khảo sát cùng với danh sách bệnh nhân nội trú.
# → BẤT KHẢ THI
# Nhóm tác giả nảy ra ý tưởng rằng sẽ … khảo sát hết nhóm bệnh nhân ngoại trú, sau đó sẽ chọn random trong số những bảng hỏi đã được khảo sát để đưa vào phân tích dữ liệu.
# → CẦN THIẾT ???

# %% [markdown]
# ## Một nghiên cứu muốn so sánh mức độ chính xác giữa chụp cắt lớp vi tính và nội soi phế quản trong việc chẩn đoán hẹp khí phế quản.
# 1. Mẫu khảo sát là các bệnh nhi tại khoa hô hấp tại BV NĐTP có tiền căn khò khè kéo dài.
# Nghiên cứu này có nên áp dụng sampling hay không, tại sao ?
# 2. Cũng cùng là nghiên cứu muốn so sánh mức độ chính xác giữa chụp cắt lớp vi tính và nội soi phế quản trong việc chẩn đoán hẹp khí phế quản.
# Mẫu khảo sát là các bệnh nhi tại khoa hô hấp tại tất cả các BV Nhi có ghi nhận tiền căn khò khè kéo dài.
# Nghiên cứu này có nên áp dụng sampling hay không, tại sao ?

# %% [markdown]
# Khi vì những lý do khách quan mà việc lấy trọn mẫu khảo sát là không khả thi (do vấn đề về thời gian, nhân lực, kinh phí), người ta quy ước một cách thức chọn ra một mẫu đại diện trong số những đối tượng có thể tiếp cận được.
#
# Tính đại diện của sample với accessible population:
# **<center>All included > Random sampling > Non random sampling</center>**
#
# Tính đại diện của sample với target population ?
#
# Những nghiên cứu liên quan tới gen thì sao ?

# %% [markdown]
# # 4. Các phương pháp sampling
#
# ## Random sampling (probability sampling)
#
# <table>
#     <caption><b>Ưu và nhược điểm của các phương pháp random sampling</b></caption>
#     <thead>
#         <tr>
#             <th>Phương pháp</th>
#             <th align='left'>Ưu điểm</th>
#             <th align='left'>Nhược điểm</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <th>Simple random</th>
#             <td><ul align='left'><li>Chỉ cần một ít kiến thức về quần thể nghiên cứu</li></ul></td>
#             <td><ul align='left'>
#                 <li>Có thể không nắm bắt được nhóm quan tâm</li>
#                 <li>Có thể không hiệu quả</li>
#                 </ul></td>
#         </tr>
#         <tr>
#             <th>Systematic</th>
#             <td><ul align='left'>
#                 <li>Dễ dàng phân tích và tinh sai số chuẩn(standard error)</li>
#                 <li>Độ chính xác cao</li>
#                 </ul></td>
#             <td><ul align='left'>
#                 <li>Thứ tự cách khoảng của các đối tượng có thể gây ra nhiễu</li>
#                 <li>Có thể không nắm bắt được nhóm quan tâm</li>
#                 <li>Có thể không hiệu quả</li>
#                 </ul></td>
#         </tr>
#         <tr>
#             <th>Stratified</th>
#             <td><ul align='left'>
#                 <li>Nắm bắt được nhóm quan tâm</li>
#                 <li>Tối ưu sắp đặt vị trí đối tượng và cho phép thay đổi tỉ lệ trong strata(nhóm nhỏ)</li>
#                 <li>Độ chính xác cao nhất</li>
#                 </ul></td>
#             <td><ul align='left'>
#                 <li>Cần kiến thức trước đó về quần thể</li>
#                 <li>Phân tích và tính toán khó khăn hơn</li>
#                 </ul></td>
#         </tr>
#         <tr>
#             <th>Cluster</th>
#             <td><ul align='left'>
#                 <li>Giảm chi phí</li>
#                 <li>Có thể lấy mẫu các đối tượng trong khi không có sẵn thông tin của đối tượng đó</li>
#                 </ul></td>
#             <td><ul align='left'>
#                 <li>Phân tích và tính toán khó khăn hơn</li>
#                 <li>Độ chính xác thấp nhất</li>
#                 </ul></td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Non random sampling (non-probability sampling)
#
# 1. **Convenience sampling:**
# Mặc dù đây không phải là random sampling nhưng lại là phương pháp sampling thông dụng nhất trong NCKH. Trong phương pháp này, nhà nghiên cứu chọn những đối tượng có sẵn và tiếp cận được.
# Vì vậy, phương pháp này đơn giản, tiện lợi, không tốn kém.
#
# 2. **Judgemental sampling:**
# Nhà nghiên cứu chọn mẫu theo lựa chọn chủ quan của bản thân.
#
# 3. **Snow-ball sampling:**
# Phương pháp này được dùng khi không có vị trí cụ thể của các đối tượng trong nghiên cứu. Thương được dùng trong nghiên cứu xã hội học, nhà nghiên cứu phát bảng câu hỏi cho 1 đối tượng và nhờ họ phát tiếp bảng câu hỏi cho đối tượng khác.

# %% [markdown]
# # 5. Cách tính cỡ mẫu
#
# 1. Ý nghĩa của công thức tính mẫu?
# 2. Liệu nếu cách chọn mẫu là non-probability sampling, ý nghĩa của công thức tính mẫu còn giữ nguyên ?
# 3. Mọi nghiên cứu đều theo công thức tính mô tả được nêu trên ?
# 4. Nếu một nghiên cứu có nhiều mục tiêu thì cỡ mẫu nên được tính theo công thức nào ?

# %% [markdown]
# ---
# **Một nghiên cứu** muốn mô tả *tỉ lệ bác sĩ điều dưỡng tại phòng lọc bệnh, phòng khám và phòng cấp cứu có thái độ tự tin trong việc xử trí và ứng phó dịch COVID-19 nếu dịch bùng phát tại Việt Nam.*.
# - Nghiên cứu lấy mẫu tại BV Nhi đồng Thành Phố.
# - Biết rằng tổng số bác sĩ điều dưỡng thoả điều kiện của nghiên cứu là khoảng **184 người.**
# - Tỉ lệ “có thái độ tự tin” trong việc xử lý dịch, do chưa có các báo cáo nghiên cứu trước đó, được chọn là **0.5**
#
# **=>n = 384**
#
# Nếu nghiên cứu chỉ để đánh giá xem nhân viên y tế Bệnh viện Nhi Đồng Thành Phố khi tiếp cận ban đầu có thể tự tin xử lý dịch được hay không, cỡ mẫu cần thiết sẽ là bao nhiêu ?
#
# ---

# %% [markdown]
# Nhằm để giảm thiểu tối đa chi phí trong việc thực hiện nghiên cứu mà vẫn đảm bảo được tính khoa học của kết quả được khảo sát, vấn đề cỡ mẫu nghiên cứu bao nhiêu là đủ được đặt ra.
#
# Cỡ mẫu nghiên cứu dựa trên giả thuyết cách chọn mẫu là probability sampling. Trong trường hợp cách lấy mẫu là non-probability, ý nghĩa của cỡ mẫu sẽ không còn như trước.
#
# Tuy vậy, cỡ mẫu của các nghiên cứu sử dụng phương pháp non-probability sampling vẫn có thể áp dụng các công thức tính mẫu bình thường (đồng thuận ngầm).

# %% [markdown]
# <table>
#     <caption><b>CRITERIA FOR ESTIMATING SAMPLE SIZE BASED ON THE STUDY DESIGN</b></caption>
#     <thead>
#         <tr>
#             <th>Design:</th>
#             <th>Descriptive</th>
#             <th>Design:</th>
#             <th>Analytical or Experimental</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Objective:</td>
#             <td>To estimate a parameter</td>
#             <td>Objective:</td>
#             <td>To test a hypothesis</td>
#         </tr>
#         <tr>
#             <td>Framework:</td>
#             <td>Sampling distribution</td>
#             <td>Framework:</td>
#             <td>Power analysis</td>
#         </tr>
#         <tr>
#             <td colspan='2'>Steps:</td>
#             <td colspan='2'>Steps:</td>
#         </tr>
#         <tr>
#             <td colspan='2'>1. Identify the major variables.</td>
#             <td colspan='2'>1. Identify the major study hypotheses.</td>
#         </tr>
#         <tr>
#             <td colspan='2'>2. Determine the types of estimates </br>of study variables, such as means or</br> proportions.</td>
#             <td colspan='2'>2. Determine the statistical tests for</br> study hypotheses, such as t-test, f-test,</br>or chi-square test.</td>
#         </tr>
#         <tr>
#             <td colspan='2'>3. Select the population or subgroups</br>of interest (based on study objectives</br>and design.</td>
#             <td colspan='2'>3. Select the population or subgroups</br>of interest (based on study hypotheses</br>and design.</td>
#         </tr>
#         <tr>
#             <td colspan='2'>4a. Indicate what you expect the</br>population value should be.</td>
#             <td colspan='2'>4a. Indicate what you expect the</br>hypothesized difference ($\Delta$) should be.</td>
#         </tr>
#         <tr>
#             <td colspan='2'>4b. Estimate the standard deviation of</br>the estimate.</td>
#             <td colspan='2'>4b. Estimate the standard deviation of</br>the difference ($\sigma$).</td>
#         </tr>
#         <tr>
#             <td colspan='2'></td>
#             <td colspan='2'>4c. Compute the effect size ($\Delta/\sigma$).</td>
#         </tr>
#         <tr>
#             <td colspan='2'>5. Decide on a desired level of</br>confidence in the estimate</br>(confidence interval).</td>
#             <td colspan='2'>5. Decide on a tolerable level of</br>error in rejecting the null hypothesis</ br>when it is <i>true</i> (alpha).</td>
#         </tr>
#         <tr>
#             <td colspan='2'>6. Decide on a tolerable range of</br> error in the estimate.</td>
#             <td colspan='2'>6. Decide on a desired level of</br>power for rejecting null hypothesis</br>when it is <i>false</i> (power).</td>
#         </tr>
#         <tr>
#             <td colspan='2'>7. Compute the sample size based</br>on study assumptions.</td>
#             <td colspan='2'>7. Compute the sample size based</br>on study assumptions.</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Sample size adjustments
# 1. Adjust for the size of population:
# $$ \frac{n}{1+(n-1)/N}$$
# 2. Adjust for the estimated sample effect:
# $$ n * \;\text{DEFF}$$
# 3. Adjust for expected response rate:
# $$ n / \;\text{response rate} $$
# 4. Adjust for the expected proportion eligible:
# $$ n / \;\text{proportion eligible} $$
# 5. Compute survey cost:
# $$ n * \;\text{estimated cost per case} $$

# %% [markdown]
# ## Các tình huống gặp phải khi tính cỡ mẫu:
# 1. Nếu y văn chưa có số liệu báo cáo, tính cỡ mẫu ra sao ?
# 2. Y văn có nhiều con số, lấy con số nào ?
# 3. Cách lấy mẫu random không phải lúc nào cũng cho mẫu khảo sát có tính đại diện. Xử trí những tình huống đó ra sao ?
# 4. Mẫu thu thập không đủ so với cỡ mẫu ước lượng bạn đầu, bạn làm gì tiếp?
